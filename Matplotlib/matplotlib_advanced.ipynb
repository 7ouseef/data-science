# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris=pd.read_csv('./datasets/iris.csv')

# %%
iris.sample(3)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 126  127            6.2           2.8            4.8           1.8
# 7      8            5.0           3.4            1.5           0.2
# 32    33            5.2           4.1            1.5           0.1
#
#             Species
# 126  Iris-virginica
# 7       Iris-setosa
# 32      Iris-setosa

# %%
iris['Species']=iris['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='jet',alpha=0.6)
plt.colorbar()

# %%
# changing size of graph
plt.figure(figsize=(15,8))
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='jet',alpha=0.6)

# %% [markdown]
# ### Annotations

# %%
batters=pd.read_csv("./datasets/batter.csv")

# %%
batters.head(3)
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577

# %%
smp_batter=batters.head(100).sample(25)

# %%
# we don't know which dot represents which batsman
plt.scatter(smp_batter['avg'],smp_batter['strike_rate'])

# %%
plt.scatter(smp_batter['avg'],smp_batter['strike_rate'],s=smp_batter['runs']/20)
for i in range(smp_batter.shape[0]):
    plt.text(smp_batter['avg'].values[i],smp_batter['strike_rate'].values[i],smp_batter['batter'].values[i])

# %%
plt.scatter(smp_batter['avg'],smp_batter['strike_rate'],s=smp_batter['runs']/20)
for i in range(smp_batter.shape[0]):
    plt.text(smp_batter['avg'].values[i],smp_batter['strike_rate'].values[i],smp_batter['batter'].values[i])

plt.axhline(130)
plt.axvline(30)
plt.axhline(140,color='green')

# %%
batters.shape
# Out:
# (605, 4)

# %% [markdown]
# ### Subplots

# %%
fig,ax=plt.subplots()
ax.plot(batters['avg'],batters['strike_rate'],'*')
ax.set_title('Title')
ax.set_xlabel('Average')
ax.set_ylabel('Strike rate')
# fig.show()
# Out:
# Text(0, 0.5, 'Strike rate')

# %%
fig,ax=plt.subplots(nrows=2,ncols=1,sharex=True)
ax[0].scatter(batters['avg'],batters['strike_rate'])
ax[0].set_title("Avg VS Strike rate")
ax[0].set_ylabel("Strike Rate")
ax[1].scatter(batters['avg'],batters['runs'])
ax[1].set_title("Avg VS Runs")
ax[1].set_xlabel("Average")
ax[1].set_ylabel("Runs")
# Out:
# Text(0, 0.5, 'Runs')

# %%
figu=plt.figure()
ax1=figu.add_subplot(2,1,1)
ax1.scatter(batters['avg'],batters['strike_rate'])
ax2=figu.add_subplot(2,1,2)
ax2.scatter(batters['avg'],batters['runs'])

# %% [markdown]
# ### 3D Scatter Plot

# %%
fig2=plt.figure()
ax11=plt.subplot(projection='3d')
ax11.scatter3D(batters['runs'],batters['avg'],batters['strike_rate'],marker='*',color='green')
ax11.set_xlabel("Runs")
ax11.set_ylabel("Average")
ax11.set_zlabel("Strike Rate")
# Out:
# C:\Users\LENOVO X1 CARBON\AppData\Local\Temp\ipykernel_7540\1495729251.py:3: MatplotlibDeprecationWarning: The clean function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use none, you no longer need to clean a Grouper instead.
#   ax11.scatter3D(batters['runs'],batters['avg'],batters['strike_rate'],marker='*',color='green')
# Text(0.5, 0, 'Strike Rate')

# %% [markdown]
# ### 3D Line Plot

# %%
x=[0,1,5]
y=[0,10,13]
z=[0,13,20]
fig2=plt.figure()
ax11=plt.subplot(projection='3d')
ax11.plot3D(x,y,z)
# Out:
# C:\Users\LENOVO X1 CARBON\AppData\Local\Temp\ipykernel_7540\3695401919.py:6: MatplotlibDeprecationWarning: The clean function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use none, you no longer need to clean a Grouper instead.
#   ax11.plot3D(x,y,z)

# %% [markdown]
# ### 3D Surface Plot

# %%
xval=np.linspace(-10,10,100)
yval=np.linspace(-10,10,100)

# %%
xx,yy=np.meshgrid(xval,yval)

# %%
zz=xx**2+yy**2

# %%
fig2=plt.figure()
ax11=plt.subplot(projection='3d')
p=ax11.plot_surface(xx,yy,zz,cmap='viridis')
fig2.colorbar(p)
# Out:
# C:\Users\LENOVO X1 CARBON\AppData\Local\Temp\ipykernel_7540\3526858923.py:3: MatplotlibDeprecationWarning: The clean function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use none, you no longer need to clean a Grouper instead.
#   p=ax11.plot_surface(xx,yy,zz,cmap='viridis')

# %% [markdown]
# ### Contour Plot

# %%
fig2=plt.figure()
ax11=plt.subplot()
p=ax11.contour(xx,yy,zz,cmap='viridis')
fig2.colorbar(p)

# %%
fig2=plt.figure()
ax11=plt.subplot()
p=ax11.contourf(xx,yy,zz,cmap='viridis')
fig2.colorbar(p)

# %% [markdown]
# ### heatmap

# %%
runs=pd.read_csv('./datasets/IPL_Ball_by_Ball_2008_2022.csv')
runs.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
t_runs=runs[(runs['ballnumber'].isin([1,2,3,4,5,6])) & (runs['batsman_run']==6)]
t_runs.head()
# Out:
#           ID  innings  overs  ballnumber       batter             bowler  \
# 16   1312200        1      2           5  YBK Jaiswal     Mohammed Shami
# 22   1312200        1      3           5  YBK Jaiswal         Yash Dayal
# 103  1312200        1     17           2     TA Boult      R Sai Kishore
# 107  1312200        1     17           6     OC McCoy      R Sai Kishore
# 142  1312200        2      3           5      MS Wade  M Prasidh Krishna
#
#       non-striker extra_type  batsman_run  extras_run  total_run  \
# 16     JC Buttler        NaN            6           0          6
# 22     JC Buttler        NaN            6           0          6
# 103       R Parag        NaN            6           0          6
# 107       R Parag        NaN            6           0          6
# 142  Shubman Gill        NaN            6           0          6
#
#      non_boundary  isWicketDelivery player_out kind fielders_involved  \
# ...

# %%
g_runs=t_runs.pivot_table(index='overs',columns='ballnumber',values='batsman_run',aggfunc='count')
g_runs
# Out:
# ballnumber    1    2    3    4    5    6
# overs
# 0             9   17   31   39   33   27
# 1            31   40   49   56   58   54
# 2            75   62   70   72   58   76
# 3            60   74   74  103   74   71
# 4            71   76  112   80   81   72
# 5            77  102   63   86   78   80
# 6            34   56   49   59   64   38
# 7            59   62   73   70   69   56
# 8            86   83   79   81   73   52
# 9            54   62   86   61   74   67
# 10           82   92   83   69   72   70
# 11           91   72   87   79   87   70
# 12           87  109   79  100  100   84
# 13          101  101   99   97   90   88
# 14           90  124  103  100   86  106
# 15          102  120  129  121  113   96
# 16          107  115  111  100  120  101
# 17          126  142  137  151  117  129
# 18          118  114  151  132  138  128
# 19          136  120  151  151  116  148

# %%
plt.imshow(g_runs)
plt.colorbar()

# %% [markdown]
# ### Dataframe plot()

# %%
s=pd.Series([1,2,3,4,5,6,7])
s.plot(kind='pie')
# Out:
# <Axes: >

# %%
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.plot(kind='scatter',x='total_bill',y='tip',marker='*',s='total_bill',title='Cost Analysis',xlabel='total bill',c='sex',cmap='viridis')
# Out:
# <Axes: title={'center': 'Cost Analysis'}, xlabel='total bill', ylabel='tip'>

# %%
tips.groupby('sex')['total_bill'].mean().plot(kind='bar',x='sex')
# Out:
# <Axes: xlabel='sex'>

# %%
batsman=pd.read_csv('./datasets/batsman_season_record.csv')
batsman
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
batsman.plot(kind='bar')
# Out:
# <Axes: >

# %%
batsman.plot(kind='bar',stacked=True)
# Out:
# <Axes: >

# %%
batsman.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
batsman['2015'].plot(kind='pie',labels=batsman['batsman'],explode=[0.25,0,0,0,0])
# Out:
# <Axes: ylabel='2015'>

# %%
batsman[['2015','2016','2017']].plot(kind='pie',subplots=True,labels=batsman['batsman'],explode=[0.25,0,0,0,0],legend=False)
# Out:
# array([<Axes: ylabel='2015'>, <Axes: ylabel='2016'>,
#        <Axes: ylabel='2017'>], dtype=object)

# %%
tips.pivot_table(index='day',columns='sex',values='total_bill',aggfunc='mean').plot(kind='line')
# Out:
# <Axes: xlabel='day'>

# %%
tips.pivot_table(index=['day','time'],columns='sex',values='total_bill',aggfunc='mean').plot(kind='line')
# Out:
# <Axes: xlabel='day,time'>
