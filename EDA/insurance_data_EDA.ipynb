# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('./datasets/insurance_data.csv')

# %%
df
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 0         0          1  39.0    male  23.2             91      Yes         0
# 1         1          2  24.0    male  30.1             87       No         0
# 2         2          3   NaN    male  33.3             82      Yes         0
# 3         3          4   NaN    male  33.7             80       No         0
# 4         4          5   NaN    male  34.1            100       No         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1340 entries, 0 to 1339
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          1340 non-null   int64
#  1   PatientID      1340 non-null   int64
#  2   age            1335 non-null   float64
#  3   gender         1340 non-null   object
#  4   bmi            1340 non-null   float64
#  5   bloodpressure  1340 non-null   int64
#  6   diabetic       1340 non-null   object
#  7   children       1340 non-null   int64
#  8   smoker         1340 non-null   object
#  9   region         1337 non-null   object
#  10  claim          1340 non-null   float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 115.3+ KB

# %%
df.describe()
# Out:
#              index    PatientID          age          bmi  bloodpressure  \
# count  1340.000000  1340.000000  1335.000000  1340.000000    1340.000000
# mean    669.500000   670.500000    38.078652    30.668955      94.157463
# std     386.968991   386.968991    11.102924     6.106735      11.434712
# min       0.000000     1.000000    18.000000    16.000000      80.000000
# 25%     334.750000   335.750000    29.000000    26.275000      86.000000
# 50%     669.500000   670.500000    38.000000    30.400000      92.000000
# 75%    1004.250000  1005.250000    47.000000    34.700000      99.000000
# max    1339.000000  1340.000000    60.000000    53.100000     140.000000
#
#           children         claim
# count  1340.000000   1340.000000
# mean      1.093284  13252.745642
# std       1.205334  12109.609288
# min       0.000000   1121.870000
# 25%       0.000000   4719.685000
# 50%       1.000000   9369.615000
# 75%       2.000000  16604.305000
# max       5.000000  63770.430000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# index            0
# PatientID        0
# age              5
# gender           0
# bmi              0
# bloodpressure    0
# diabetic         0
# children         0
# smoker           0
# region           3
# claim            0
# dtype: int64

# %%
df['age'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['age'].plot(kind='kde',grid=True)
# Out:
# <Axes: ylabel='Density'>

# %%
df['age'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['age'].skew()
# Out:
# 0.11361133741072633

# %%
df['age'].isnull().sum()
# Out:
# 5

# %%
df['gender'].value_counts()
# Out:
# gender
# male      678
# female    662
# Name: count, dtype: int64

# %%
df['gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='gender'>

# %%
df['gender'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 0         0          1  39.0    male  23.2             91      Yes         0
# 1         1          2  24.0    male  30.1             87       No         0
# 2         2          3   NaN    male  33.3             82      Yes         0
# 3         3          4   NaN    male  33.7             80       No         0
# 4         4          5   NaN    male  34.1            100       No         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# ...

# %%
df['smoker'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='smoker'>

# %%
df['smoker'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['children'].value_counts()
# Out:
# children
# 0    576
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64

# %%
df['children'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='children'>

# %%
df['children'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['children'].isnull().sum()
# Out:
# 0

# %%
df['diabetic'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='diabetic'>

# %%
df['diabetic'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['region'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # age - claim

# %%
plt.scatter(df['age'],df['claim'])
plt.axhline(df['claim'].mean(),color='red')

# %%
pd.Series([df[df['claim']<15000].shape[0],df.shape[0]-df[df['claim']<15000].shape[0]]).plot(kind='pie',labels=['Less than 15000','Greater than 15000'],autopct='%0.1f%%',title='Distribution of claims on age based on mean')
# Out:
# <Axes: title={'center': 'Distribution of claims on age based on mean'}>

# %%
sns.scatterplot(data=df[df['claim']<15000],x='age',y='claim')
df[df['claim']<15000][['age','claim']].corr()

# no correlation batween age and claim amount,but most of the claims are 
# clustered between 0 to 15000 and are distributed equally acorss diff age
# Out:
#             age     claim
# age    1.000000  0.040011
# claim  0.040011  1.000000

# %% [markdown]
# # gender - claim

# %%
df[['gender','claim']].groupby('gender').mean()
# Out:
#                claim
# gender
# female  12569.578897
# male    13919.790457

# %%
sns.stripplot(data=df,x='gender',y='claim',hue='gender',jitter=0.25)
# Out:
# <Axes: xlabel='gender', ylabel='claim'>

# %%
sns.swarmplot(data=df,x='gender',y='claim',hue='gender')
# Out:
# D:\Software\anaconda\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 5.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='gender', ylabel='claim'>
# D:\Software\anaconda\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 26.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\Software\anaconda\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 30.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(data=df,x='gender',y='claim')
# Out:
# <Axes: xlabel='gender', ylabel='claim'>

# %%
sns.violinplot(data=df,x='gender',y='claim')
# distribution is same for both males and females,males have more spread of data for values greater than median
# Out:
# <Axes: xlabel='gender', ylabel='claim'>

# %% [markdown]
# # bmi - claim

# %%
def bmi_fun(bmi):
    if bmi<18.5:
        return "underweight"
    elif bmi>=18.5 and bmi<=24.9:
        return "normal"
    elif bmi>=25 and bmi<=29.9:
        return "overweight"
    else:
        return "obese"
df['bmi_cat']=df['bmi'].apply(bmi_fun)

# %%
df['bmi_cat'].value_counts()
# Out:
# bmi_cat
# obese          708
# overweight     389
# normal         223
# underweight     20
# Name: count, dtype: int64

# %%
df['bmi_cat'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='bmi_cat'>

# %%
df[['bmi_cat','claim']].groupby('bmi_cat').agg([min,(lambda x: np.percentile(x,q=25)),'median'
                                                ,(lambda x: np.percentile(x,q=75)),max,'mean','std'])
# minimum claim of underweight people is the most highest among all
# despite the difference in frequency of all categories the minimum and maximum values
# for all categories are near to each other,whereas there is slight diff in median values
# Out:
#                claim                                                          \
#                  min <lambda_0>   median  <lambda_1>       max          mean
# bmi_cat
# normal       1121.87  4018.8300  8603.82  15035.4200  35069.37  10340.598744
# obese        1131.51  5145.9775  9937.21  19870.7550  63770.43  15531.992599
# overweight   1252.41  4687.8000  8615.30  15518.1800  38245.59  11000.079306
# underweight  1621.34  2751.6300  6759.26  12923.1675  32734.19   8852.201500
#
#
#                       std
# bmi_cat
# normal        7506.312889
# obese        14552.097000
# overweight    8036.943136
# underweight   7735.038414

# %%
df[['bmi_cat','claim']].groupby('bmi_cat').mean().sort_values('claim',ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='bmi_cat'>

# %%
sns.boxplot(data=df,x='bmi_cat',y='claim')
plt.grid()
plt.axhline(5000)
# mean claim of obese people is highly influenced by outliers

# %%
sns.violinplot(data=df,x='bmi_cat',y='claim')
# normal and overweight people have almost same distribution of claim
# Out:
# <Axes: xlabel='bmi_cat', ylabel='claim'>

# %% [markdown]
# # bloodpressure - claim

# %%
def bp_fun(bp):
    if bp<80:
        return 'optimal'
    elif bp>=80 and bp<=84:
        return 'normal'
    elif bp>=85 and bp<=89:
        return 'high normal'
    elif bp>=90 and bp<=99:
        return 'grade 1'
    elif bp>=100 and bp<=109:
        return 'grade 2'
    else:
        return 'grade 3'

df['bp_cat']=df['bloodpressure'].apply(bp_fun)

# %%
df['bp_cat'].value_counts()
# Out:
# bp_cat
# grade 1        498
# normal         268
# high normal    259
# grade 2        209
# grade 3        106
# Name: count, dtype: int64

# %%
df['bp_cat'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='bp_cat'>

# %%
df[['bp_cat','claim']].groupby('bp_cat').agg([min,(lambda x: np.percentile(x,q=25)),'median'
                                                ,(lambda x: np.percentile(x,q=75)),max,'mean','std'])

# grdae 2 and grade 3 BP patients tend to reuqest higher claim amount as compared to others
# Out:
#                claim                                              \
#                  min  <lambda_0>     median <lambda_1>       max
# bp_cat
# grade 1      1121.87   4201.1150   7444.780  12268.645  60021.40
# grade 2      1137.01   9957.7200  12495.290  20630.280  63770.43
# grade 3      9861.03  28589.3075  37122.265  42496.245  58571.07
# high normal  1131.51   3871.2950   7371.770  12778.685  55135.40
# normal       1135.94   3827.4725   7540.235  12380.400  47496.49
#
#
#                      mean           std
# bp_cat
# grade 1      10427.033916   9778.079670
# grade 2      16858.307512  12325.195941
# grade 3      35296.037170  10684.093362
# high normal  10311.605444   9458.595130
# normal        9815.463619   8338.465793

# %%
sns.boxplot(data=df,x='bp_cat',y='claim')

# grade 2 have more outliers than grade 3 so we can be sure that grade 3 patients will request higher claim amount
# Out:
# <Axes: xlabel='bp_cat', ylabel='claim'>

# %%
sns.violinplot(data=df,x='bp_cat',y='claim')

# grade 1,high normal and normal patients have almost same distribution but grade 1 mean is highly influenced by outliers
# Out:
# <Axes: xlabel='bp_cat', ylabel='claim'>

# %% [markdown]
# # bp - smoker - claim and bmi - diabetic - claim

# %%
df.pivot_table(index='bp_cat',columns='smoker',values='claim',aggfunc='mean')
# Out:
# smoker                 No           Yes
# bp_cat
# grade 1       7672.123959  30163.028197
# grade 2      10997.127379  30137.543750
# grade 3      20748.620870  39327.248916
# high normal   7680.344956  28331.753030
# normal        7730.373277  24663.834242

# %%
sns.heatmap(df.pivot_table(index='bp_cat',columns='smoker',values='claim',aggfunc='mean'))
# smokers and grade 3 patients requested for hgiher claims
# Out:
# <Axes: xlabel='smoker', ylabel='bp_cat'>

# %%
df.pivot_table(index='bmi_cat',columns='diabetic',values='claim',aggfunc='mean')
# Out:
# diabetic               No           Yes
# bmi_cat
# normal       10161.082381  10500.337881
# obese        15589.983289  15465.942779
# overweight   11141.256359  10841.158689
# underweight   8167.817000   9536.586000

# %%
sns.heatmap(df.pivot_table(index='bmi_cat',columns='diabetic',values='claim',aggfunc='mean'))
# Out:
# <Axes: xlabel='diabetic', ylabel='bmi_cat'>

# %%
df.pivot_table(index='bp_cat',columns='bmi_cat',values='claim',aggfunc='mean')
# Out:
# bmi_cat            normal         obese    overweight  underweight
# bp_cat
# grade 1       9060.284483  11675.447328   9246.207676     4641.350
# grade 2      15724.245926  19208.428318  14050.752778    10625.200
# grade 3      24995.330000  38109.275833  24424.948235          NaN
# high normal   9087.500577  11117.494800  10038.855875     2680.230
# normal        9531.297115   9934.736231   9436.956026    13414.815

# %%
sns.heatmap(df.pivot_table(index='bp_cat',columns='bmi_cat',values='claim',aggfunc='mean'))
# normal,obese and overweight people with grade 3 bp wll request higher claim amount
# grade 2 obese people also tend to request higher claim amount
# Out:
# <Axes: xlabel='bmi_cat', ylabel='bp_cat'>

# %%
df.pivot_table(index=['bp_cat','smoker'],columns=['bmi_cat','diabetic'],values='claim',aggfunc='mean')
# Out:
# bmi_cat                   normal                       obese                \
# diabetic                      No           Yes            No           Yes
# bp_cat      smoker
# grade 1     No       7123.231842   7065.612857   7947.562353   8313.513878
#             Yes     19279.713333  19323.401250  41045.771538  41985.288667
# grade 2     No      14261.560000  12164.160000  10657.280526  11371.216190
#             Yes     17869.214286  19081.683333  44484.057857  42304.406154
# grade 3     No               NaN  27375.900000  22002.017143  21142.862857
#             Yes     21223.680000  25459.023333  42178.337632  40512.130625
# high normal No       8595.874000   7162.496923   8791.700179   6705.176250
#             Yes     19555.175000  18824.320000  39120.470000  41779.602000
# normal      No       4797.133333   6381.731429   8704.608125   7892.329322
#             Yes     22839.538333  19746.494286  38673.960000  38187.870000
#
# ...

# %%
sns.heatmap(df.pivot_table(index=['bp_cat','smoker'],columns=['bmi_cat','diabetic'],values='claim',aggfunc='mean'))

# grade 1,2,3 and high normal smoker people who have
# obsese(does not depend on diabetic or not) requested higher claim than others

# grade 3 smoker who are overwiehgt and have diabeties also requests high claim amount
# Out:
# <Axes: xlabel='bmi_cat-diabetic', ylabel='bp_cat-smoker'>

# %%
# checking age of underweight smoker and non diabetic people as they claim hgih amount
df[df['bmi_cat']=='underweight']['age'].mean()
# they are not teenagers,mostly married people
# Out:
# 38.5

# %%
# checking their children
df[(df['smoker']=='Yes') &(df['bmi_cat']=='underweight') & (df['diabetic']=='No')] # only one patient so maybe an outlier
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 1187   1187       1188  25.0  female  17.8             83       No         2
#
#      smoker     region     claim      bmi_cat  bp_cat
# 1187    Yes  northwest  32734.19  underweight  normal

# %%
df['children'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='children'>

# %%
df[['children','claim']].groupby('children').mean().plot(kind='bar')
# Out:
# <Axes: xlabel='children'>

# %%
sns.boxplot(data=df,x='children',y='claim',hue='gender')
# Out:
# <Axes: xlabel='children', ylabel='claim'>

# %%
sns.violinplot(data=df,x='children',y='claim',hue='gender',split=True)
plt.grid()
# almost same distribution but still males with 2 to 3 children
# tend to request higher claim where as females category and other category of males is influenced by outliers

# %%
sns.displot(data=df,x='age',y='claim',col='gender',kind='hist')

# males in their 20s,30s and 50s tend to request lower claim amount
# females data is equally distributed

# %% [markdown]
# # Conclusions
# ## Univariate analysis
# - `age:`
#     - most people have age between 25 to 50
# - `gender:`
#     - equal ratio of male and female
# - `smoker`:
#     - most people are non-smokers
# - `children`:
#     - most people have no children
# - `diabetic`:
#     - equal number of people are diabtic and non diabetic
# ## Bivariate analysis
